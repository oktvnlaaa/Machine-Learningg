# %% [markdown]
# <a href="https://colab.research.google.com/github/oktvnlaaa/Machine-Learningg/blob/main/Pertemuan_2_Yola_Okta_Vina_2117051052.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pertemuan 2 Machine Learning

# %% [markdown]
# # Library
#
#
#
# *   Install Library
# *   Deklarasi Library
# *   Library bisa disebut sebagai kumpulan kode yang dapat digunakan berulang kali dalam program yang berbeda
# *   https://www.geeksforgeeks.org/libraries-in-python/

# %%
# install library mlxtend
# !pip install mlxtend
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np

# import apriori from library mixtend
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# # Dataset
#
#
#
# *   Membuat dataset transaksi sebagai dataframe
# *   cek dataset transaksi

# %%
# membuat data tabular yang terdiri dari data transaksi
df = pd.DataFrame(
    {
        "ID Transaksi": pd.Series([1, 2, 3, 4, 5]),
        "Item": pd.Series([["Susu", "Roti", "Biskuit", "Mentega"], \
                          ["Susu", "Biskuit", "Gula", "Kopi"], \
                          ["Gula", "Kopi", "Susu"], ["Kopi", "Biskuit", "Susu", "Gula"], \
                          ["Mentega", "Roti", "Kopi"]]),
    }
)

# %% [markdown]
# # Encoding Data Transaksi

# %%
df = df.explode('Item')
df
# Out:
#    ID Transaksi     Item
# 0             1     Susu
# 0             1     Roti
# 0             1  Biskuit
# 0             1  Mentega
# 1             2     Susu
# 1             2  Biskuit
# 1             2     Gula
# 1             2     Kopi
# 2             3     Gula
# 2             3     Kopi
# 2             3     Susu
# 3             4     Kopi
# 3             4  Biskuit
# 3             4     Susu
# 3             4     Gula
# 4             5  Mentega
# 4             5     Roti
# 4             5     Kopi

# %%
basket = (df.groupby (['ID Transaksi', 'Item'])['Item']. count()\
          .unstack(). reset_index(). fillna(0) \
          .set_index('ID Transaksi'))
basket.head()
# Out:
# Item          Biskuit  Gula  Kopi  Mentega  Roti  Susu
# ID Transaksi
# 1                 1.0   0.0   0.0      1.0   1.0   1.0
# 2                 1.0   1.0   1.0      0.0   0.0   1.0
# 3                 0.0   1.0   1.0      0.0   0.0   1.0
# 4                 1.0   1.0   1.0      0.0   0.0   1.0
# 5                 0.0   0.0   1.0      1.0   1.0   0.0

# %% [markdown]
# # Algoritma Apriori
#
# Eksekusi algoritma apriori menggunakan library mlextend dengan fungsi apriori

# %% [markdown]
# # Apriori Tahap 1
#
# Eliminasi itemset berdasarkan minimum support

# %%
# set minimum support 60%
frequent_itemsets = apriori(basket, min_support = 0.6, use_colnames = True)

# print(list(frequent_itemset))
frequent_itemsets
# Out:
#    support            itemsets
# 0      0.6           (Biskuit)
# 1      0.6              (Gula)
# 2      0.8              (Kopi)
# 3      0.8              (Susu)
# 4      0.6     (Susu, Biskuit)
# 5      0.6        (Kopi, Gula)
# 6      0.6        (Susu, Gula)
# 7      0.6        (Susu, Kopi)
# 8      0.6  (Susu, Kopi, Gula)

# %% [markdown]
# # Apriori Tahap 2
#
# Perhitungan Confidence

# %%
rules = association_rules(frequent_itemsets, metric ="confidence", min_threshold = 0.6)
rules [["antecedents", "consequents", "support","confidence"]]
# Out:
#      antecedents   consequents  support  confidence
# 0         (Susu)     (Biskuit)      0.6        0.75
# 1      (Biskuit)        (Susu)      0.6        1.00
# 2         (Kopi)        (Gula)      0.6        0.75
# 3         (Gula)        (Kopi)      0.6        1.00
# 4         (Susu)        (Gula)      0.6        0.75
# 5         (Gula)        (Susu)      0.6        1.00
# 6         (Susu)        (Kopi)      0.6        0.75
# 7         (Kopi)        (Susu)      0.6        0.75
# 8   (Susu, Kopi)        (Gula)      0.6        1.00
# 9   (Susu, Gula)        (Kopi)      0.6        1.00
# 10  (Kopi, Gula)        (Susu)      0.6        1.00
# 11        (Susu)  (Kopi, Gula)      0.6        0.75
# 12        (Kopi)  (Susu, Gula)      0.6        0.75
# 13        (Gula)  (Susu, Kopi)      0.6        1.00

# %% [markdown]
# # TUGAS RESPONSI 2 Machine Learning
#
# Menggunakan data yang sama, selesai kasus apriori ini dengan minimum support 40%

# %% [markdown]
# # Apriori Tahap 1

# %%
# set minimum support 40%
frequent_itemsets = apriori(basket, min_support = 0.4, use_colnames = True)

# print(list(frequent_itemset))
frequent_itemsets
# Out:
#     support                     itemsets
# 0       0.6                    (Biskuit)
# 1       0.6                       (Gula)
# 2       0.8                       (Kopi)
# 3       0.4                    (Mentega)
# 4       0.4                       (Roti)
# 5       0.8                       (Susu)
# 6       0.4              (Gula, Biskuit)
# 7       0.4              (Kopi, Biskuit)
# 8       0.6              (Susu, Biskuit)
# 9       0.6                 (Kopi, Gula)
# 10      0.6                 (Susu, Gula)
# 11      0.6                 (Susu, Kopi)
# 12      0.4              (Roti, Mentega)
# 13      0.4        (Kopi, Gula, Biskuit)
# 14      0.4        (Susu, Gula, Biskuit)
# 15      0.4        (Susu, Kopi, Biskuit)
# 16      0.6           (Susu, Kopi, Gula)
# 17      0.4  (Susu, Kopi, Gula, Biskuit)

# %% [markdown]
# # Apriori Tahap 2

# %%
rules = association_rules(frequent_itemsets, metric ="confidence", min_threshold = 0.4)
rules [["antecedents", "consequents", "support","confidence"]]
# Out:
#               antecedents            consequents  support  confidence
# 0                  (Gula)              (Biskuit)      0.4    0.666667
# 1               (Biskuit)                 (Gula)      0.4    0.666667
# 2                  (Kopi)              (Biskuit)      0.4    0.500000
# 3               (Biskuit)                 (Kopi)      0.4    0.666667
# 4                  (Susu)              (Biskuit)      0.6    0.750000
# 5               (Biskuit)                 (Susu)      0.6    1.000000
# 6                  (Kopi)                 (Gula)      0.6    0.750000
# 7                  (Gula)                 (Kopi)      0.6    1.000000
# 8                  (Susu)                 (Gula)      0.6    0.750000
# 9                  (Gula)                 (Susu)      0.6    1.000000
# 10                 (Susu)                 (Kopi)      0.6    0.750000
# 11                 (Kopi)                 (Susu)      0.6    0.750000
# ...
